# %%
import sys
sys.path.insert(0,'/Users/nakaa1/code/py/PsychRNN')

import psychrnn
from psychrnn.tasks import rdm as rd
from psychrnn.backend.models.basic import Basic

import tensorflow as tf
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# define params globally first before passing to RDM, mess w/ model params and explain what can do. (can turn on and off dale's law). some masking, input output connectivity. train_params variables stuff

# %%
dt = 10 # time-step
tau = 100 # intrinsic time constant of neural state decay
T = 2000 # time to run for (number of steps is T/dt)
N_batch = 50 # number of trials per training step
N_rec = 50 # number of recurrent units
name = 'basicModel'

# %%
rdm = rd.RDM(dt = dt, tau = tau, T = T, N_batch = N_batch)

# %% [markdown]
# RDM puts the params passed in as well as other generated params into a dict we can then use to create our model.

# %%
params = rdm.__dict__
print(params)
# Out:
# {'N_batch': 50, 'N_in': 2, 'N_out': 2, 'dt': 10, 'tau': 100, 'T': 2000, 'alpha': 0.1, 'N_steps': 200}

# %% [markdown]
# Generate *N_batch* trials to be used in training

# %%
gen = rdm.batch_generator()

# %% [markdown]
# We add in a few params that Basic(RNN) needs but that RDM doesn't generate for us.

# %%
params['name'] = name #Used to scope out a namespace for global variables.
params['N_rec'] = N_rec

# %% [markdown]
# There are some other optional parameters we can add in:

# %%
params['dale_ratio'] = None # Default: None -- when the dale_ratio is set, dale's law is applied
params['rec_noise'] = 0.0 # Default: 0.0 -- how much noise to add to the new_state calculation
params['W_in_train'] = True # Indicates whether W_in is trainable. Default: True
params['W_rec_train'] = True # Indicates whether W_rec is trainable. Default: True
params['W_out_train'] = True # Indicates whether W_out is trainable. Default: True
params['b_rec_train'] = True # Indicates whether b_rec is trainable. Default: True
params['b_out_train'] = True # Indicates whether b_out is trainable. Default: True
params['init_state_train'] = True # Indicates whether init_state is trainable. Default: True
params['load_weights_path'] = None # When given a path, loads weights from file in that path. Default: None

# %% [markdown]
# Instantiate our model

# %%
basicModel = Basic(params)
# Out:
# WARNING:tensorflow:From /Users/nakaa1/anaconda3/envs/psychrnn/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# Start a tensorflow session with loss, regularization, predictions, and regularized loss defined.

# %%
basicModel.build()

# %% [markdown]
# Set the training parameters for our model. All of the parameters below are optional.

# %%
train_params = {}
train_params['save_weights_path'] =  '../weights/refactor_weights.npz' # Where to save the model after training. Default: None
train_params['training_iters'] = 100000 # number of iterations to train for Default: 10000
train_params['learning_rate'] = .001 # Sets learning rate if use default optimizer Default: .001
train_params['loss_epoch'] = 10 # Compute and record loss every 'loss_epoch' epochs. Default: 10
train_params['verbosity'] = True # If true, prints information as training progresses. Default: True
train_params['save_training_weights_epoch'] = 100 # save training weights every 'save_training_weights_epoch' epochs. Default: 100
train_params['training_weights_path'] = None # where to save training weights as training progresses. Default: None
train_params['generator_function'] = None # replaces trial_batch_generator with the generator_function when not none. Default: None
train_params['optimizer'] = tf.train.AdamOptimizer(learning_rate=train_params['learning_rate']) # What optimizer to use to compute gradients. Default: tf.train.AdamOptimizer(learning_rate=train_params['learning_rate'])
train_params['clip_grads'] = True # If true, clip gradients by norm 1. Default: True

# %% [markdown]
# Train our model.

# %%
basicModel.train(gen, train_params)
# Out:
# Iter 500, Minibatch Loss= 0.194868
# Iter 1000, Minibatch Loss= 0.119480
# Iter 1500, Minibatch Loss= 0.112705
# Iter 2000, Minibatch Loss= 0.111083
# Iter 2500, Minibatch Loss= 0.100533
# Iter 3000, Minibatch Loss= 0.059653
# Iter 3500, Minibatch Loss= 0.027510
# Iter 4000, Minibatch Loss= 0.022073
# Iter 4500, Minibatch Loss= 0.013092
# Iter 5000, Minibatch Loss= 0.018245
# Training weights saved in file: None100
# Iter 5500, Minibatch Loss= 0.017274
# Iter 6000, Minibatch Loss= 0.029967
# Iter 6500, Minibatch Loss= 0.020605
# Iter 7000, Minibatch Loss= 0.016383
# Iter 7500, Minibatch Loss= 0.020797
# Iter 8000, Minibatch Loss= 0.018722
# Iter 8500, Minibatch Loss= 0.015734
# Iter 9000, Minibatch Loss= 0.018298
# Iter 9500, Minibatch Loss= 0.014404
# Iter 10000, Minibatch Loss= 0.011816
# Training weights saved in file: None200
# Iter 10500, Minibatch Loss= 0.012536
# Iter 11000, Minibatch Loss= 0.012556
# Iter 11500, Minibatch Loss= 0.009438
# Iter 12000, Minibatch Loss= 0.009760
# Iter 12500, Minibatch Loss= 0.011715
# Iter 13000, Minibatch Loss= 0.011806
# Iter 13500, Minibatch Loss= 0.009170
# Iter 14000, Minibatch Loss= 0.012715
# Iter 14500, Minibatch Loss= 0.012048
# Iter 15000, Minibatch Loss= 0.009100
# Training weights saved in file: None300
# Iter 15500, Minibatch Loss= 0.011175
# Iter 16000, Minibatch Loss= 0.011116
# Iter 16500, Minibatch Loss= 0.009166
# Iter 17000, Minibatch Loss= 0.007869
# Iter 17500, Minibatch Loss= 0.006431
# Iter 18000, Minibatch Loss= 0.010903
# Iter 18500, Minibatch Loss= 0.008420
# Iter 19000, Minibatch Loss= 0.009025
# Iter 19500, Minibatch Loss= 0.008124
# Iter 20000, Minibatch Loss= 0.007012
# Training weights saved in file: None400
# Iter 20500, Minibatch Loss= 0.006289
# Iter 21000, Minibatch Loss= 0.006211
# Iter 21500, Minibatch Loss= 0.007233
# Iter 22000, Minibatch Loss= 0.005469
# Iter 22500, Minibatch Loss= 0.005784
# Iter 23000, Minibatch Loss= 0.007047
# Iter 23500, Minibatch Loss= 0.005938
# Iter 24000, Minibatch Loss= 0.005668
# Iter 24500, Minibatch Loss= 0.005974
# Iter 25000, Minibatch Loss= 0.006281
# Training weights saved in file: None500
# Iter 25500, Minibatch Loss= 0.007615
# Iter 26000, Minibatch Loss= 0.005877
# Iter 26500, Minibatch Loss= 0.005568
# Iter 27000, Minibatch Loss= 0.005522
# Iter 27500, Minibatch Loss= 0.005234
# Iter 28000, Minibatch Loss= 0.005284
# Iter 28500, Minibatch Loss= 0.005389
# Iter 29000, Minibatch Loss= 0.005539
# Iter 29500, Minibatch Loss= 0.004197
# Iter 30000, Minibatch Loss= 0.004898
# Training weights saved in file: None600
# Iter 30500, Minibatch Loss= 0.006746
# Iter 31000, Minibatch Loss= 0.005950
# Iter 31500, Minibatch Loss= 0.006613
# Iter 32000, Minibatch Loss= 0.004789
# Iter 32500, Minibatch Loss= 0.005088
# Iter 33000, Minibatch Loss= 0.007108
# Iter 33500, Minibatch Loss= 0.011006
# Iter 34000, Minibatch Loss= 0.022714
# Iter 34500, Minibatch Loss= 0.006254
# Iter 35000, Minibatch Loss= 0.004908
# Training weights saved in file: None700
# Iter 35500, Minibatch Loss= 0.005026
# Iter 36000, Minibatch Loss= 0.004642
# Iter 36500, Minibatch Loss= 0.004173
# Iter 37000, Minibatch Loss= 0.003860
# Iter 37500, Minibatch Loss= 0.006134
# Iter 38000, Minibatch Loss= 0.004743
# Iter 38500, Minibatch Loss= 0.004327
# Iter 39000, Minibatch Loss= 0.004661
# Iter 39500, Minibatch Loss= 0.003770
# Iter 40000, Minibatch Loss= 0.003737
# Training weights saved in file: None800
# Iter 40500, Minibatch Loss= 0.004173
# Iter 41000, Minibatch Loss= 0.004076
# Iter 41500, Minibatch Loss= 0.003765
# Iter 42000, Minibatch Loss= 0.003975
# Iter 42500, Minibatch Loss= 0.003812
# Iter 43000, Minibatch Loss= 0.004087
# Iter 43500, Minibatch Loss= 0.003654
# Iter 44000, Minibatch Loss= 0.003542
# Iter 44500, Minibatch Loss= 0.004834
# Iter 45000, Minibatch Loss= 0.003923
# Training weights saved in file: None900
# Iter 45500, Minibatch Loss= 0.003623
# Iter 46000, Minibatch Loss= 0.003261
# Iter 46500, Minibatch Loss= 0.003666
# Iter 47000, Minibatch Loss= 0.003363
# Iter 47500, Minibatch Loss= 0.003138
# Iter 48000, Minibatch Loss= 0.003121
# Iter 48500, Minibatch Loss= 0.003331
# Iter 49000, Minibatch Loss= 0.003627
# Iter 49500, Minibatch Loss= 0.003184
# Iter 50000, Minibatch Loss= 0.004824
# Training weights saved in file: None1000
# Iter 50500, Minibatch Loss= 0.006443
# Iter 51000, Minibatch Loss= 0.003335
# Iter 51500, Minibatch Loss= 0.003760
# Iter 52000, Minibatch Loss= 0.003547
# Iter 52500, Minibatch Loss= 0.003102
# Iter 53000, Minibatch Loss= 0.003054
# Iter 53500, Minibatch Loss= 0.003592
# Iter 54000, Minibatch Loss= 0.003015
# Iter 54500, Minibatch Loss= 0.002852
# Iter 55000, Minibatch Loss= 0.003065
# Training weights saved in file: None1100
# Iter 55500, Minibatch Loss= 0.003115
# Iter 56000, Minibatch Loss= 0.003094
# Iter 56500, Minibatch Loss= 0.003039
# Iter 57000, Minibatch Loss= 0.003542
# Iter 57500, Minibatch Loss= 0.003603
# Iter 58000, Minibatch Loss= 0.002837
# Iter 58500, Minibatch Loss= 0.002966
# Iter 59000, Minibatch Loss= 0.002849
# Iter 59500, Minibatch Loss= 0.002838
# Iter 60000, Minibatch Loss= 0.002844
# Training weights saved in file: None1200
# Iter 60500, Minibatch Loss= 0.002698
# Iter 61000, Minibatch Loss= 0.002561
# Iter 61500, Minibatch Loss= 0.002476
# Iter 62000, Minibatch Loss= 0.002456
# Iter 62500, Minibatch Loss= 0.002654
# Iter 63000, Minibatch Loss= 0.002568
# Iter 63500, Minibatch Loss= 0.002488
# Iter 64000, Minibatch Loss= 0.002754
# Iter 64500, Minibatch Loss= 0.003239
# Iter 65000, Minibatch Loss= 0.003130
# Training weights saved in file: None1300
# Iter 65500, Minibatch Loss= 0.003820
# Iter 66000, Minibatch Loss= 0.002467
# Iter 66500, Minibatch Loss= 0.002227
# Iter 67000, Minibatch Loss= 0.002368
# Iter 67500, Minibatch Loss= 0.002704
# Iter 68000, Minibatch Loss= 0.002234
# Iter 68500, Minibatch Loss= 0.002362
# Iter 69000, Minibatch Loss= 0.002428
# Iter 69500, Minibatch Loss= 0.002134
# Iter 70000, Minibatch Loss= 0.002391
# Training weights saved in file: None1400
# Iter 70500, Minibatch Loss= 0.002125
# Iter 71000, Minibatch Loss= 0.002303
# Iter 71500, Minibatch Loss= 0.002371
# Iter 72000, Minibatch Loss= 0.002063
# Iter 72500, Minibatch Loss= 0.002146
# Iter 73000, Minibatch Loss= 0.002112
# Iter 73500, Minibatch Loss= 0.002517
# Iter 74000, Minibatch Loss= 0.002700
# Iter 74500, Minibatch Loss= 0.002116
# Iter 75000, Minibatch Loss= 0.002797
# Training weights saved in file: None1500
# Iter 75500, Minibatch Loss= 0.002171
# Iter 76000, Minibatch Loss= 0.002321
# Iter 76500, Minibatch Loss= 0.002207
# Iter 77000, Minibatch Loss= 0.002274
# Iter 77500, Minibatch Loss= 0.003142
# Iter 78000, Minibatch Loss= 0.003609
# Iter 78500, Minibatch Loss= 0.004171
# Iter 79000, Minibatch Loss= 0.003953
# Iter 79500, Minibatch Loss= 0.007049
# Iter 80000, Minibatch Loss= 0.002812
# Training weights saved in file: None1600
# Iter 80500, Minibatch Loss= 0.002844
# Iter 81000, Minibatch Loss= 0.002584
# Iter 81500, Minibatch Loss= 0.001904
# Iter 82000, Minibatch Loss= 0.001955
# Iter 82500, Minibatch Loss= 0.001997
# Iter 83000, Minibatch Loss= 0.002422
# Iter 83500, Minibatch Loss= 0.001706
# Iter 84000, Minibatch Loss= 0.002053
# Iter 84500, Minibatch Loss= 0.001984
# Iter 85000, Minibatch Loss= 0.001668
# Training weights saved in file: None1700
# Iter 85500, Minibatch Loss= 0.001678
# Iter 86000, Minibatch Loss= 0.001988
# Iter 86500, Minibatch Loss= 0.001814
# Iter 87000, Minibatch Loss= 0.001832
# Iter 87500, Minibatch Loss= 0.001761
# Iter 88000, Minibatch Loss= 0.002071
# Iter 88500, Minibatch Loss= 0.001703
# Iter 89000, Minibatch Loss= 0.002137
# Iter 89500, Minibatch Loss= 0.001600
# Iter 90000, Minibatch Loss= 0.001735
# Training weights saved in file: None1800
# Iter 90500, Minibatch Loss= 0.001706
# Iter 91000, Minibatch Loss= 0.001487
# Iter 91500, Minibatch Loss= 0.001789
# Iter 92000, Minibatch Loss= 0.001719
# Iter 92500, Minibatch Loss= 0.001489
# Iter 93000, Minibatch Loss= 0.001548
# Iter 93500, Minibatch Loss= 0.001561
# Iter 94000, Minibatch Loss= 0.001440
# Iter 94500, Minibatch Loss= 0.001466
# Iter 95000, Minibatch Loss= 0.001478
# Training weights saved in file: None1900
# Iter 95500, Minibatch Loss= 0.001649
# Iter 96000, Minibatch Loss= 0.001496
# Iter 96500, Minibatch Loss= 0.001448
# Iter 97000, Minibatch Loss= 0.001621
# Iter 97500, Minibatch Loss= 0.001510
# Iter 98000, Minibatch Loss= 0.001443
# Iter 98500, Minibatch Loss= 0.001343
# Iter 99000, Minibatch Loss= 0.001270
# Iter 99500, Minibatch Loss= 0.001351
# Optimization finished!
# Model saved in file: ../weights/refactor_weights.npz
# ([0.19486813,
#   0.11948015,
#   0.112705186,
#   0.111083396,
#   0.10053282,
#   0.05965321,
#   0.027509531,
#   0.022073407,
#   0.013091574,
#   0.018244578,
#   0.017273838,
#   0.029967295,
#   0.02060477,
#   0.016382964,
#   0.020797152,
#   0.018721536,
#   0.015734393,
#   0.01829787,
#   0.014403761,
#   0.011816049,
#   0.012536139,
#   0.012555626,
#   0.009437989,
#   0.009760314,
#   0.011715152,
#   0.011806362,
#   0.009169533,
#   0.012715022,
#   0.012048117,
#   0.009100182,
#   0.011174611,
#   0.011116054,
#   0.00916608,
#   0.0078687025,
#   0.0064307,
#   0.010903203,
#   0.008419571,
#   0.009024735,
#   0.0081238765,
#   0.007012372,
#   0.006289272,
#   0.00621103,
#   0.0072333138,
#   0.0054686563,
#   0.0057837367,
#   0.0070465333,
#   0.0059384387,
#   0.0056677964,
#   0.005974057,
#   0.006280861,
#   0.0076146605,
#   0.0058772666,
#   0.0055680717,
#   0.005522121,
#   0.0052342257,
#   0.0052841976,
#   0.0053886324,
#   0.0055390657,
#   0.00419739,
#   0.004897932,
#   0.006745977,
#   0.0059500965,
#   0.0066125933,
#   0.004788608,
#   0.005087542,
#   0.0071079102,
#   0.0110058915,
#   0.022714222,
#   0.006254334,
#   0.0049079317,
#   0.005025742,
#   0.004641813,
#   0.0041731885,
#   0.0038595363,
#   0.0061338213,
#   0.004743292,
#   0.0043269005,
#   0.004660768,
#   0.0037704902,
#   0.0037369174,
#   0.0041733827,
#   0.004076034,
#   0.0037648103,
#   0.0039748484,
#   0.0038120903,
#   0.0040871915,
#   0.003653704,
#   0.0035422721,
#   0.004834406,
#   0.0039227884,
#   0.0036231629,
#   0.003261367,
#   0.0036655602,
#   0.0033633637,
#   0.0031376514,
#   0.0031214764,
#   0.0033306656,
#   0.003627214,
#   0.0031837914,
#   0.004823827,
#   0.006443092,
#   0.0033351448,
#   0.003760131,
#   0.0035473725,
#   0.0031015312,
#   0.0030541886,
#   0.0035918022,
#   0.0030148784,
#   0.0028521481,
#   0.0030648783,
#   0.0031152165,
#   0.0030940427,
#   0.0030387877,
#   0.003541558,
#   0.0036025685,
#   0.0028366956,
#   0.00296627,
#   0.0028488082,
#   0.0028384281,
#   0.0028441348,
#   0.0026975027,
#   0.0025608654,
#   0.0024761818,
#   0.002456474,
#   0.0026539024,
#   0.002568493,
#   0.002487551,
#   0.0027543239,
#   0.0032385346,
#   0.0031302352,
#   0.0038196952,
#   0.0024674535,
#   0.0022271555,
#   0.0023679538,
#   0.0027041915,
#   0.0022335632,
#   0.002362365,
#   0.0024281426,
#   0.0021342204,
#   0.0023913472,
#   0.0021253414,
#   0.002303199,
#   0.0023712611,
#   0.00206299,
#   0.0021462825,
#   0.0021117642,
#   0.0025171484,
#   0.0027004518,
#   0.0021155362,
#   0.002797399,
#   0.00217144,
#   0.002320932,
#   0.00220667,
#   0.0022739419,
#   0.003141532,
#   0.0036092147,
#   0.004170823,
#   0.003952527,
#   0.0070492914,
#   0.0028115646,
#   0.0028435355,
#   0.0025843135,
#   0.0019044372,
#   0.001955083,
#   0.0019972571,
#   0.0024221614,
#   0.0017063599,
#   0.0020530073,
#   0.0019837918,
#   0.0016681122,
#   0.0016776104,
#   0.001988348,
#   0.0018137739,
#   0.0018320648,
#   0.0017613062,
#   0.0020705278,
#   0.0017033266,
#   0.00213694,
#   0.0016001078,
#   0.0017347834,
#   0.0017058277,
#   0.001487161,
#   0.0017890749,
#   0.0017189041,
#   0.0014892975,
#   0.0015482625,
#   0.0015610876,
#   0.0014396483,
#   0.0014660425,
#   0.0014777578,
#   0.0016487804,
#   0.001496137,
#   0.0014477693,
#   0.0016206888,
#   0.0015103784,
#   0.0014432945,
#   0.0013434719,
#   0.0012701651,
#   0.0013508446],
#  771.0244061946869,
#  29.50458288192749)

# %% [markdown]
# ### Plot results

# %% [markdown]
# Extract the next trial from the generator

# %%
x,y,m = next(gen)

# %% [markdown]
# Plot the x value of the trial -- for the RDM, this includes two input neurons with different coherence.

# %%
plt.plot(range(0, len(x[0,:,:])*dt,dt), x[0,:,:])
plt.ylabel("Input Magnitude")
plt.xlabel("Time (ms)")
plt.title("Input Data")
# Out:
# Text(0.5, 1.0, 'Input Data')

# %% [markdown]
# Run the trained model on this trial (not included in the training set).

# %%
results = basicModel.test(x)
output = results[0]
state_var = results[1]

# %%
# Out:
# (50, 200, 2)

# %%
plt.plot(range(0, len(output[0,:,:])*dt,dt),output[0,:,:])
plt.ylabel("Activity of Output Unit")
plt.xlabel("Time (ms)")
plt.title("Output on New Sample")
# Out:
# Text(0.5, 1.0, 'Output on New Sample')

# %%
plt.plot(range(0, len(state_var[0,:,:])*dt,dt),state_var[0,:,:])
plt.ylabel("State Variable Value")
plt.xlabel("Time (ms)")
plt.title("Evolution of State Variables over Time")
# Out:
# Text(0.5, 1.0, 'Evolution of State Variables over Time')

# %% [markdown]
# Clean up the model to clear out the tensorflow namespace

# %%
basicModel.destruct()
